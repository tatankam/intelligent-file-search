# %% [markdown]
# # File Metadata and Content Index Generator
#
# This Python script automates the creation of a metadata and content index for a simulated filesystem. It generates up to 100 JSON files, each representing a document with a variety of attributes—such as filename, path, size, creation and modification dates, content chunks, file type, and tags.
# This tool is designed to help prototype, test, and develop file-based search, retrieval, or recommendation systems that rely on metadata and content for enhanced searchability.
#
# ## Features
#
# - **Content-Driven Filenames**
#   - Filenames are generated based on the actual content of the file, extracting a keyword from the first content chunk.
#   - The base filename is limited to a maximum of 8 characters (before the file extension).
# - **Randomized File Paths**
#   - Each file is assigned a random path starting from root (`/`), up to three directory levels deep.
# - **Comprehensive Metadata**
#   - **filename** (content-based, up to 8 chars)
#   - **path**
#   - **size** (in kilobytes)
#   - **creation_date** (randomly between 2001 and 2025)
#   - **last_modified_date** (after creation_date, within the same range)
#   - **content_chunks** (1–3 realistic text or table chunks per file)
#   - **file_type** (`xlsx`, `pdf`, `docx`, `txt`, `pptx`, `md`)
#   - **tags** (1–3 tags per file: `sport`, `cinema`, `fashion`, `cars`; some files have multiple tags)
# - **Realistic Content**
#   - Content chunks are generated using the Faker library, ensuring relevance to the assigned tags.
#   - **Text files:** Paragraphs are tailored to the file’s tags.
#   - **Spreadsheets (xlsx):** Tables are generated with relevant headers and sample data.
# - **Flexible Output**
#   - The script outputs a JSON index for each file, making it easy to ingest into search engines, vector databases, or other metadata-driven applications.
#
# ## Example
#
# Each generated JSON file looks like this:

# %% [markdown]
# ```
# {
#   "filename": "basketba.pdf",
#   "path": "/alpha/beta/basketba.pdf",
#   "sizekB": 1234,
#   "last_modified_date": "2023-05-15",
#   "creation_date": "2023-01-10",
#   "content_chunks": [
#     "The basketball player scored a goal. The championship was intense. The athlete trained hard."
#   ],
#   "file_type": "pdf",
#   "tags": ["sport"]
# }
# ```

# %% [markdown]
# ---
#
# ## About Production File Extraction
#
# This script is intended for development and testing. In a production environment, you would typically use specialized tools to extract metadata and content from real files. Here are some examples of how this is done:
#
# - **PDF Documents:**
#   - **Tool:** PyPDF2 or Apache Tika
#   - **What is extracted:**
#     - Basic metadata (author, title, creation/modification dates)
#     - Full text content for indexing or search
# - **Word Documents:**
#   - **Tool:** python-docx or Apache Tika
#   - **What is extracted:**
#     - Document properties (author, title, keywords)
#     - Paragraphs and tables for content analysis
# - **Excel Files:**
#   - **Tool:** openpyxl or Apache Tika
#   - **What is extracted:**
#     - Sheet names, column headers, and cell data
#     - Custom metadata stored in properties
# - **Text Files:**
#   - **Tool:** Built-in Python file handling or Apache Tika
#   - **What is extracted:**
#     - File content for indexing or search
#     - Stat metadata (size, timestamps)
# - **Markdown Files:**
#   - **Tool:** Built-in Python file handling or specialized parsers
#   - **What is extracted:**
#     - Markdown content for rendering or indexing
#     - Front matter (YAML metadata, if present)
#
# These tools and techniques allow you to extract both structured metadata (like creation date and author) and unstructured content (like paragraphs and tables) from a wide range of file formats, supporting robust search and analysis workflows.

# %%
#!pip install faker

# %%
import os
import json
import random
import re
from datetime import datetime, date, timedelta
from faker import Faker

fake = Faker()

# Ensure output directory exists
os.makedirs('../dataset/generated_files', exist_ok=True)

file_types = ['xlsx', 'pdf', 'docx', 'txt', 'pptx', 'md']
tags_list = ['sport', 'cinema', 'fashion', 'cars']

def random_date(start_year, end_year):
    """Generate a random date between start_year and end_year."""
    year = random.randint(start_year, end_year)
    month = random.randint(1, 12)
    day = random.randint(1, 28)
    return date(year, month, day)

def random_path(max_levels=3):
    """Generate a random path starting with / and up to max_levels deep."""
    levels = random.randint(1, max_levels)
    path = "/"
    for _ in range(levels):
        path += fake.word().lower() + "/"
    return path.rstrip('/')

def clean_filename(keyword):
    """Remove special characters from keyword."""
    cleaned = re.sub(r'[^a-zA-Z0-9_]', '', keyword)
    if not cleaned:
        return "file"
    return cleaned.lower()

def extract_keyword(content_chunk):
    """Extract a unique keyword from the content chunk."""
    words = content_chunk.split()
    for word in words:
        word_lower = word.lower()
        if word_lower not in {'the', 'a', 'an', 'and', 'name', 'title', 'designer', 'model', 'event', 'collection', 'score', 'year', 'brand'}:
            return clean_filename(word)
    # If no unique word found, fall back to a random tag
    return clean_filename(random.choice(['sport', 'cinema', 'fashion', 'cars']))

for i in range(1, 101):
    file_type = random.choice(file_types)
    num_tags = random.randint(1, 3)
    tags = random.sample(tags_list, num_tags) if num_tags <= len(tags_list) else tags_list.copy()
    num_chunks = random.randint(1, 3)
    content_chunks = []
    for _ in range(num_chunks):
        chunk = ""
        if file_type in ['txt', 'md', 'pdf', 'docx', 'pptx']:
            for tag in tags:
                if tag == 'sport':
                    chunk += fake.paragraph(nb_sentences=1, ext_word_list=['football', 'basketball', 'tennis', 'championship', 'athlete']) + " "
                elif tag == 'cinema':
                    chunk += fake.paragraph(nb_sentences=1, ext_word_list=['movie', 'actor', 'director', 'scene', 'award']) + " "
                elif tag == 'fashion':
                    chunk += fake.paragraph(nb_sentences=1, ext_word_list=['dress', 'designer', 'trend', 'runway', 'model']) + " "
                elif tag == 'cars':
                    chunk += fake.paragraph(nb_sentences=1, ext_word_list=['car', 'engine', 'speed', 'model', 'race']) + " "
            content_chunks.append(chunk.strip())
        elif file_type == 'xlsx':
            table = ""
            if 'sport' in tags:
                table += "name,event,score\nJohn,football,3\nLisa,tennis,2\n"
            if 'cinema' in tags:
                table += "title,director,year\nInception,Christopher Nolan,2010\n"
            if 'fashion' in tags:
                table += "designer,collection,season\nChanel,Spring,2023\n"
            if 'cars' in tags:
                table += "model,brand,year\nModel 3,Tesla,2022\n"
            content_chunks.append(table.strip())

    # Extract keyword from first content chunk
    keyword = extract_keyword(content_chunks[0])
    keyword = keyword[:8]  # Truncate to 8 chars
    filename = f"{keyword}.{file_type}"

    path = random_path(max_levels=3) + "/" + filename
    size = random.randint(100, 10000)

    creation_date = random_date(2001, 2025)
    last_modified_date = creation_date + timedelta(days=random.randint(1, (date(2025,12,31) - creation_date).days))
    creation_date = creation_date.isoformat()
    last_modified_date = last_modified_date.isoformat()

    data = {
        "filename": filename,
        "path": path,
        "sizekB": size,
        "last_modified_date": last_modified_date,
        "creation_date": creation_date,
        "content_chunks": content_chunks,
        "file_type": file_type,
        "tags": tags
    }

    with open(f'../dataset/generated_files/file_{i}_index.json', 'w') as f:
        json.dump(data, f, indent=2)

print("Generated 100 JSON index files in 'generated_files' directory!")
# Out:
# Generated 100 JSON index files in 'generated_files' directory!

# %% [markdown]
# # JSON Index to JSONL Combiner
#
# This script reads all JSON metadata files from `../dataset/generated_files` and combines them into a single JSONL file (`../dataset/combined_index.jsonl`). Each line in the resulting file is a standalone JSON object representing the metadata and content of one file.
#
# ## Usage
#
# 1. Place your individual JSON index files in `../dataset/generated_files`.
# 2. Run this script.
# 3. The output will be a JSONL file at `../dataset/combined_index.jsonl`, with one JSON object per line.
#
# **Fields included:**
# - `filename`
# - `path`
# - `sizekB`
# - `last_modified_date`
# - `creation_date`
# - `content_chunks`
# - `file_type`
# - `tags`

# %%
import os
import json
from datetime import datetime, timezone

input_dir = '../dataset/generated_files'
output_file = '../dataset/combined_index.jsonl'

def convert_to_timestamp(datestr):
    try:
        # Convert "YYYY-MM-DD" to timestamp (UTC)
        return int(datetime.fromisoformat(datestr).replace(tzinfo=timezone.utc).timestamp())
    except Exception as e:
        print(f"Error parsing date '{datestr}': {e}")
        return None

def normalize_entry(data, file_id):
    creation_ts = convert_to_timestamp(data.get("creation_date"))
    modified_ts = convert_to_timestamp(data.get("last_modified_date"))

    return {
        "id": file_id,
        "Filename": data.get("filename"),
        "Path": data.get("path"),
        "Size_kB": float(data.get("sizekB", 0)),
        "Content": " ".join(data.get("content_chunks", [])),
        "File_Type": [data.get("file_type")] if data.get("file_type") else [],
        "Tags": data.get("tags", []),
        "Creation_Date": creation_ts,
        "Last_Modified_Date": modified_ts,
    }

with open(output_file, 'w', encoding='utf-8') as outfile:
    file_counter = 1
    for fname in sorted(os.listdir(input_dir)):
        if fname.endswith('.json'):
            with open(os.path.join(input_dir, fname), 'r', encoding='utf-8') as f:
                data = json.load(f)
                normalized = normalize_entry(data, f"id_{file_counter}")
                json.dump(normalized, outfile)
                outfile.write('\n')
                file_counter += 1

print(f"Combined JSONL written to {output_file}")
# Out:
# Combined JSONL written to ../dataset/combined_index.jsonl

# %%
import pandas as pd
import json

# Read the normalized JSONL file into a list of dicts
records = []
with open("../dataset/combined_index.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        records.append(json.loads(line))

# Create DataFrame with a descriptive name
filedf = pd.DataFrame(records)

# Show all content in columns without truncation
pd.set_option('display.max_colwidth', None)

# Print available columns
print(list(filedf.columns))

# Display a few selected columns in a nice format
filedf[[
    "id",
    "Filename",
    "File_Type",
    "Tags",
    "Path",
    "Creation_Date",
    "Last_Modified_Date",
    "Content"
]].head(50)
# Out:
# ['id', 'Filename', 'Path', 'Size_kB', 'Content', 'File_Type', 'Tags', 'Creation_Date', 'Last_Modified_Date']
#        id       Filename File_Type                      Tags  \
# 0    id_1      tennis.md      [md]          [sport, fashion]
# 1    id_2    tennis.pptx    [pptx]    [sport, fashion, cars]
# 2    id_3       race.txt     [txt]                    [cars]
# 3    id_4     dress.docx    [docx]           [fashion, cars]
# 4    id_5      scene.txt     [txt]                  [cinema]
# 5    id_6         car.md      [md]            [cars, cinema]
# 6    id_7       race.txt     [txt]             [cars, sport]
# 7    id_8  nameeven.xlsx    [xlsx]          [fashion, sport]
# 8    id_9  titledir.xlsx    [xlsx]            [cinema, cars]
# 9   id_10  champion.docx    [docx]  [sport, fashion, cinema]
# 10  id_11  nameeven.xlsx    [xlsx]    [sport, fashion, cars]
# 11  id_12     tennis.txt     [txt]          [sport, fashion]
# 12  id_13   director.txt     [txt]                  [cinema]
# 13  id_14     scene.docx    [docx]         [cinema, fashion]
# 14  id_15  nameeven.xlsx    [xlsx]  [fashion, cinema, sport]
# 15  id_16  football.docx    [docx]          [sport, fashion]
# 16  id_17   basketba.txt     [txt]           [sport, cinema]
# 17  id_18      race.docx    [docx]                    [cars]
# 18  id_19  nameeven.xlsx    [xlsx]  [fashion, cinema, sport]
# 19  id_20      award.pdf     [pdf]     [cinema, sport, cars]
# 20  id_21     trend.docx    [docx]                 [fashion]
# 21  id_22    basketba.md      [md]          [sport, fashion]
# 22  id_23      movie.txt     [txt]                  [cinema]
# 23  id_24    athlete.pdf     [pdf]                   [sport]
# 24  id_25     speed.pptx    [pptx]           [cars, fashion]
# 25  id_26  basketba.docx    [docx]                   [sport]
# 26  id_27      movie.txt     [txt]         [cinema, fashion]
# 27  id_28  director.pptx    [pptx]   [cinema, cars, fashion]
# 28  id_29     movie.pptx    [pptx]            [cinema, cars]
# 29  id_30        race.md      [md]                    [cars]
# 30  id_31    engine.docx    [docx]    [cars, fashion, sport]
# 31  id_32       race.txt     [txt]                    [cars]
# 32  id_33        race.md      [md]     [cars, cinema, sport]
# 33  id_34        car.txt     [txt]                    [cars]
# 34  id_35  designer.xlsx    [xlsx]           [cars, fashion]
# 35  id_36  nameeven.xlsx    [xlsx]           [cinema, sport]
# 36  id_37     runway.txt     [txt]                 [fashion]
# 37  id_38   director.txt     [txt]            [cinema, cars]
# 38  id_39  director.docx    [docx]         [cinema, fashion]
# 39  id_40         car.md      [md]                    [cars]
# 40  id_41       award.md      [md]  [cinema, fashion, sport]
# 41  id_42       dress.md      [md]  [fashion, sport, cinema]
# 42  id_43  football.pptx    [pptx]                   [sport]
# 43  id_44     athlete.md      [md]  [sport, cinema, fashion]
# 44  id_45      runway.md      [md]           [fashion, cars]
# 45  id_46  nameeven.xlsx    [xlsx]          [sport, fashion]
# 46  id_47      tennis.md      [md]                   [sport]
# 47  id_48  nameeven.xlsx    [xlsx]                   [sport]
# 48  id_49       actor.md      [md]  [cinema, fashion, sport]
# 49  id_50       trend.md      [md]           [fashion, cars]
#
#                                       Path  Creation_Date  Last_Modified_Date  \
# 0                        /almost/tennis.md     1574121600          1744502400
# 1                        /area/tennis.pptx     1471651200          1619136000
# 2       /worry/brother/particular/race.txt     1708473600          1709942400
# 3                 /without/role/dress.docx     1378425600          1443484800
# 4              /room/eye/medical/scene.txt     1341964800          1755043200
# 5           /individual/bar/reality/car.md     1295654400          1596153600
# 6                   /money/health/race.txt     1366934400          1491955200
# 7                     /other/nameeven.xlsx     1186876800          1433721600
# 8                /husband/it/titledir.xlsx     1708300800          1714262400
# 9                /kid/spring/champion.docx     1113523200          1732579200
# 10                /fear/long/nameeven.xlsx     1552176000          1557446400
# 11     /name/describe/beautiful/tennis.txt     1002585600          1714089600
# 12                /themselves/director.txt     1323648000          1686096000
# 13                   /whose/cut/scene.docx     1573257600          1717286400
# 14                    /offer/nameeven.xlsx     1689897600          1690070400
# 15                 /describe/football.docx     1626566400          1728950400
# 16                 /talk/also/basketba.txt     1098057600          1390003200
# 17                       /lawyer/race.docx     1164326400          1490745600
# 18                     /thus/nameeven.xlsx     1086220800          1578441600
# 19        /financial/under/three/award.pdf     1006560000          1323993600
# 20               /central/reach/trend.docx     1759881600          1762646400
# 21            /everything/sort/basketba.md     1393286400          1763337600
# 22              /store/drive/its/movie.txt     1195257600          1241827200
# 23  /still/everything/economic/athlete.pdf     1275004800          1392508800
# 24       /foreign/ground/behind/speed.pptx     1288224000          1698624000
# 25            /according/lay/basketba.docx     1098230400          1257465600
# 26          /message/safe/travel/movie.txt     1336953600          1539302400
# 27          /subject/hundred/director.pptx     1519689600          1597017600
# 28                   /recognize/movie.pptx     1430006400          1629676800
# 29               /anyone/head/wall/race.md     1590969600          1642636800
# 30        /usually/blue/leader/engine.docx      980467200          1060560000
# 31               /upon/guess/show/race.txt     1681084800          1683936000
# 32                   /feeling/drop/race.md     1320537600          1371254400
# 33                       /increase/car.txt     1556064000          1583625600
# 34            /international/designer.xlsx     1049587200          1643932800
# 35              /though/rate/nameeven.xlsx     1538956800          1739059200
# 36                   /site/next/runway.txt     1261699200          1614816000
# 37               /scene/court/director.txt     1078790400          1332115200
# 38       /politics/candidate/director.docx     1600214400          1604707200
# 39                 /space/challenge/car.md     1731024000          1738022400
# 40        /market/discover/effort/award.md     1039996800          1504569600
# 41           /visit/yourself/blue/dress.md     1435968000          1520208000
# 42         /by/foreign/while/football.pptx     1613347200          1670630400
# 43                     /million/athlete.md     1707177600          1718236800
# 44        /like/particularly/let/runway.md     1261699200          1662336000
# 45               /course/gun/nameeven.xlsx     1265673600          1544745600
# 46                         /good/tennis.md     1724112000          1758672000
# 47                      /law/nameeven.xlsx     1265932800          1717545600
# 48              /report/newspaper/actor.md     1326067200          1690934400
# 49                        /wonder/trend.md     1209254400          1324080000
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Content
# 0                                                                                                                                                                                                                                                                    Tennis championship basketball football tennis. Trend dress trend. Football football athlete football basketball football tennis tennis. Designer model runway trend designer designer designer dress.
# 1                                                                                                                                                                                                                                                                                                                        Tennis basketball championship athlete championship basketball. Model trend trend model designer designer. Car model speed model race model speed.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                    Race model race speed. Race speed car car speed model.
# 3                                                                                                                                                                                                                                                                                                   Dress model model trend runway trend model runway. Engine model model engine engine speed engine. Designer designer trend model trend designer. Speed speed race speed.
# 4                                                                                                                                                                                                                                                                                                                                                Scene scene movie director actor award director. Movie actor director. Scene movie award award movie award director movie.
# 5                                                                                                                                                                                                                                                                                                                                                                                                           Car speed race speed model race. Actor actor award movie award.
# 6                                                                                                                                                                                                                                                                     Model race car car car car model. Championship football championship athlete football. Model model speed speed race. Football championship football football basketball basketball football football.
# 7                                                                                                                                                                        name,event,score\nJohn,football,3\nLisa,tennis,2\ndesigner,collection,season\nChanel,Spring,2023 name,event,score\nJohn,football,3\nLisa,tennis,2\ndesigner,collection,season\nChanel,Spring,2023 name,event,score\nJohn,football,3\nLisa,tennis,2\ndesigner,collection,season\nChanel,Spring,2023
# 8                                                                                                                                                                                                                                                                                                                                                                               title,director,year\nInception,Christopher Nolan,2010\nmodel,brand,year\nModel 3,Tesla,2022
# 9                                       Championship football tennis tennis basketball. Trend designer trend dress. Actor award director scene actor. Football football tennis championship football basketball tennis. Trend trend runway designer model runway. Actor actor director director movie director movie. Athlete basketball basketball basketball basketball athlete. Designer model trend model dress designer trend. Movie scene actor scene director award.
# 10                                                     name,event,score\nJohn,football,3\nLisa,tennis,2\ndesigner,collection,season\nChanel,Spring,2023\nmodel,brand,year\nModel 3,Tesla,2022 name,event,score\nJohn,football,3\nLisa,tennis,2\ndesigner,collection,season\nChanel,Spring,2023\nmodel,brand,year\nModel 3,Tesla,2022 name,event,score\nJohn,football,3\nLisa,tennis,2\ndesigner,collection,season\nChanel,Spring,2023\nmodel,brand,year\nModel 3,Tesla,2022
# 11                                                                                                                                                                                                                                                                                                                                                                                          Tennis football football basketball basketball. Model model trend runway model.
# 12                                                                                                                                                                                                                                                                                                                                                                                                            Director award director award. Movie actor actor actor movie.
# 13                                                                                                                                                                                                                                                                                                                                                                                 Scene movie actor movie actor movie. Designer designer runway dress runway trend runway.
# 14                                                                                                                                                          name,event,score\nJohn,football,3\nLisa,tennis,2\ntitle,director,year\nInception,Christopher Nolan,2010\ndesigner,collection,season\nChanel,Spring,2023 name,event,score\nJohn,football,3\nLisa,tennis,2\ntitle,director,year\nInception,Christopher Nolan,2010\ndesigner,collection,season\nChanel,Spring,2023
# 15                                                                                                                                                                                                                                                                                                                                                                                            Football basketball championship basketball. Trend runway runway dress dress.
# 16                                                                                                                                                                                                                                                                                                                                                                                      Basketball athlete football football tennis basketball. Director actor actor movie.
# 17                                                                                                                                                                                                                                                                                                                                                                      Race engine car engine model speed car. Speed speed engine car race. Car speed race car race speed.
# 18  name,event,score\nJohn,football,3\nLisa,tennis,2\ntitle,director,year\nInception,Christopher Nolan,2010\ndesigner,collection,season\nChanel,Spring,2023 name,event,score\nJohn,football,3\nLisa,tennis,2\ntitle,director,year\nInception,Christopher Nolan,2010\ndesigner,collection,season\nChanel,Spring,2023 name,event,score\nJohn,football,3\nLisa,tennis,2\ntitle,director,year\nInception,Christopher Nolan,2010\ndesigner,collection,season\nChanel,Spring,2023
# 19                                                                                                                                                                                                                                                                                                                      Award movie scene director scene movie. Football basketball football basketball basketball athlete basketball. Speed model model model model model.
# 20                                                                                                                                                                                                                                                                                                                                                                             Trend dress trend runway. Designer runway model. Dress dress trend dress trend model runway.
# 21                                                                                                                                                                                                                                                                                                                                                               Basketball championship athlete basketball basketball basketball football. Runway designer designer model.
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                 Movie scene director. Movie actor scene.
# 23                                                                                                                                                                                                                                                                                                                           Athlete football athlete football athlete basketball championship athlete. Basketball athlete basketball athlete football tennis championship.
# 24                                                                                                                                                                                                                              Speed speed engine engine. Designer designer dress designer runway runway. Engine race model race race model car. Dress trend dress model designer runway. Engine engine speed engine engine car car. Runway designer trend designer dress.
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                     Basketball athlete football athlete.
# 26                                                                                                                                                                                                                                                                                                                                                    Movie actor movie director director. Model runway runway. Movie scene movie award. Designer model trend runway trend.
# 27                                                                                                                                                                                                                                  Director actor movie movie movie director. Engine car race speed engine engine race model. Designer designer trend trend trend. Director award award scene. Model car engine engine race car race. Dress designer designer dress model.
# 28                                                                                                                                                                                                                                                                                 Movie scene scene award. Speed race car race. Actor scene actor. Speed model model speed car engine. Actor scene scene scene movie scene. Model model model car model speed race engine.
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                             Race model car speed engine.
# 30                                                                                                                                                   Engine race car car car engine. Dress designer model designer dress runway dress. Tennis athlete basketball football championship athlete basketball. Speed model car engine model race. Runway runway model runway designer runway designer designer. Basketball football basketball tennis football tennis football.
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                    Race model model model engine engine.
# 32                                                                                                                                                                                                                                                                                                                                                Model race car engine engine. Movie award director movie award. Championship football championship championship football.
# 33                                                                                                                                                                                                                                                                                                                                                                                                                          Car model race car model. Speed engine car car.
# 34                                                                                                                                                                                                                                                                                                                                                                                     designer,collection,season\nChanel,Spring,2023\nmodel,brand,year\nModel 3,Tesla,2022
# 35                                                                                                                                                                                                                                                                                                                                                                  name,event,score\nJohn,football,3\nLisa,tennis,2\ntitle,director,year\nInception,Christopher Nolan,2010
# 36                                                                                                                                                                                                                                                                                                                                         Runway designer designer model runway dress dress. Trend dress dress designer trend dress dress. Runway designer dress designer.
# 37                                                                                                                                                                                                                                                                                                                                                                                              Director award movie award actor scene. Model model model race model speed.
# 38                                                                                                                                                                                                                                                                                                                                                                                               Director award director scene movie scene award. Trend runway dress model.
# 39                                                                                                                                                                                                                                                                                                                                                                                                                                                 Car car car model model.
# 40                                                                                                                                                                                                  Award movie actor award movie scene scene scene. Runway trend model. Tennis tennis tennis basketball tennis. Director movie movie movie director director. Runway model dress dress designer runway. Tennis basketball basketball athlete basketball football football.
# 41                                                                                                                                                                                                                                                                                                                                Dress runway model runway model trend. Championship championship tennis championship championship athlete. Scene actor director director.
# 42                                                                                                                                                                                                                                                                                                                                                                                                   Football tennis athlete tennis. Tennis basketball basketball football.
# 43       Athlete athlete football football basketball tennis basketball tennis. Award movie movie director award director award movie. Designer dress trend trend dress dress. Tennis athlete championship football championship. Director director director director actor award actor scene. Dress trend dress runway runway. Athlete basketball athlete football. Award award director movie scene director scene. Trend designer designer dress designer runway runway.
# 44                                                                                                                                                                                                                                                                                     Runway model designer runway trend dress. Speed engine model. Dress model model trend model. Model race engine model race engine car. Model model runway. Engine race car car model.
# 45                                                                                                                                                                                                                                                                        name,event,score\nJohn,football,3\nLisa,tennis,2\ndesigner,collection,season\nChanel,Spring,2023 name,event,score\nJohn,football,3\nLisa,tennis,2\ndesigner,collection,season\nChanel,Spring,2023
# 46                                                                                                                                                                                                                                                                                              Tennis championship football championship football. Football championship championship basketball. Championship basketball football tennis basketball athlete championship.
# 47                                                                                                                                                                                                                                                                                                                                                                        name,event,score\nJohn,football,3\nLisa,tennis,2 name,event,score\nJohn,football,3\nLisa,tennis,2
# 48                                                                                                                                                                                                                        Actor scene award award scene. Runway runway trend runway model. Football athlete athlete championship. Movie director award actor actor scene actor. Trend model designer trend dress trend model. Football basketball tennis football football.
# 49                                                                                                                                                                                                                                                    Trend trend model designer model model runway. Car car car race race. Model designer dress model dress. Speed model engine car engine model model. Trend designer dress model dress. Car race car engine speed speed.

# %% [markdown]
# ## Create file_type and tags categories

# %%
import json

file_types = set()
tags = set()

with open(output_file, "r", encoding="utf-8") as f:
    for line in f:
        if not line.strip():
            continue
        obj = json.loads(line)
        # File_Type is a list, so iterate and strip each
        if "File_Type" in obj and obj["File_Type"]:
            file_types.update([ft.strip() for ft in obj["File_Type"]])
        # Tags is a list
        if "Tags" in obj and obj["Tags"]:
            tags.update([t.strip() for t in obj["Tags"]])

result = {
    "FileType": sorted(file_types),
    "Tags": sorted(tags),
}

with open("../dataset/categories.json", "w", encoding="utf-8") as f:
    json.dump(result, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ### I want collection_name=filesearch so I start superlinked.server with APP_ID=filesearch

# %% [markdown]
# ```shell
# python3.12.3 -m venv .venv
# . .venv/bin/activate
# pip install -r requirements.txt
# APP_ID=filesearch APP_MODULE_PATH=superlinked_app python -m superlinked.server
# ```

# %% [markdown]
# ### Split loading combined_index.jsonl and I created more batches

# %%
import json
import requests

def send_batches(data, batch_size=50):
    for i in range(0, len(data), batch_size):
        batch = data[i:i+batch_size]
        response = requests.post(
            'http://localhost:8080/data-loader/file_document/run',
            json=batch,
            headers={'Accept': 'application/json'}
        )
        print(f"Batch {i//batch_size + 1} response:", response.status_code, response.text)

# Load your full dataset
with open('../dataset/combined_index.jsonl', 'r', encoding='utf-8') as f:
    data = [json.loads(line) for line in f]

send_batches(data, batch_size=10)  # Adjust batch size as needed
# Out:
# Batch 1 response: 202 {"result":"Background task successfully started with name: file_document"}
# Batch 2 response: 202 {"result":"Background task successfully started with name: file_document"}
# Batch 3 response: 202 {"result":"Background task successfully started with name: file_document"}
# Batch 4 response: 202 {"result":"Background task successfully started with name: file_document"}
# Batch 5 response: 202 {"result":"Background task successfully started with name: file_document"}
# Batch 6 response: 202 {"result":"Background task successfully started with name: file_document"}
# Batch 7 response: 202 {"result":"Background task successfully started with name: file_document"}
# Batch 8 response: 202 {"result":"Background task successfully started with name: file_document"}
# Batch 9 response: 202 {"result":"Background task successfully started with name: file_document"}
# Batch 10 response: 202 {"result":"Background task successfully started with name: file_document"}

# %% [markdown]
# #### Comparing to the original curl command, curl works faster
#
# ```shell
# curl -X POST http://<server-host>:<port>/data-loader/file_document/run -H 'accept: application/json' -d ''
#
# ```

# %% [markdown]
# # Integration with monkeSearch
# ## I want to use linux_dump.json as source

# %% [markdown]
# #### Create linux_dump.jsonl

# %%
import json
import time

input_dump_file = '../dataset/linux_dump.json'
output_dump_file = '../dataset/linux_dump.jsonl'

def to_unix_timestamp(dt_str):
    try:
        return int(time.mktime(time.strptime(dt_str[:19], '%Y-%m-%dT%H:%M:%S')))
    except Exception:
        return None

with open(input_dump_file, 'r', encoding='utf-8') as f:
    data = json.load(f)

with open(output_dump_file, 'w', encoding='utf-8') as f_out:
    for idx, entry in enumerate(data, 1):
        jsonl_obj = {
            "id": f"id_{idx}",
            "Path": entry["Path"],
            "Name": entry["Name"],
            "Size": entry["Size"],  # keeping original size in bytes
            "ContentType": entry.get("ContentType", ""),
            "Kind": entry.get("Kind", ""),
            "CreationDate": to_unix_timestamp(entry["CreationDate"]),
            "ContentChangeDate": to_unix_timestamp(entry["ContentChangeDate"]),
        }
        f_out.write(json.dumps(jsonl_obj) + '\n')

print(f"Conversion complete with original fields: {output_dump_file}")
# Out:
# Conversion complete with original fields: ../dataset/linux_dump.jsonl

# %% [markdown]
# #### Create categories.json from linux_dump.jsonl

# %%
import json

kind_set = set()
input_file = '../dataset/linux_dump.jsonl'
output_file = '../dataset/categories.json'

with open(input_file, "r", encoding="utf-8") as f:
    for line in f:
        if not line.strip():
            continue
        obj = json.loads(line)
        kind_value = obj.get("Kind")
        if kind_value:
            kind_set.add(kind_value.strip())

result = {
    "Kind": sorted(kind_set),
}

with open(output_file, "w", encoding="utf-8") as f:
    json.dump(result, f, ensure_ascii=False, indent=2)

print(f"Categories file created at {output_file}")
# Out:
# Categories file created at ../dataset/categories.json

# %% [markdown]
# ### Analyze with pandas

# %%
import pandas as pd
import json

# Read the normalized JSONL file into a list of dicts
records = []
with open("../dataset/linux_dump.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        records.append(json.loads(line))

# Create DataFrame with a descriptive name
filedf = pd.DataFrame(records)

# Show all content in columns without truncation
pd.set_option('display.max_colwidth', None)

# Print available columns
print(list(filedf.columns))

# Display a few selected columns in a nice format
filedf = filedf[[
    "Path",
    "Name",
    "Size",
    "ContentType",
    "Kind",
    "CreationDate",
    "ContentChangeDate"
]]
filedf.head(50)
# Integration with monkeSearch
# Out:
# ['id', 'Path', 'Name', 'Size', 'ContentType', 'Kind', 'CreationDate', 'ContentChangeDate']
#                                                                          Path  \
# 0                                      /home/biso/Desktop/ProRealTime.desktop
# 1   /home/biso/Desktop/brave-ejhkdoiecgkmdpomoahkdihbcldkgjci-Default.desktop
# 2                                                 /home/biso/Desktop/WiFIEolo
# 3                                       /home/biso/Desktop/cod eolo 906791918
# 4                                         /home/biso/Downloads/ledger2024.pdf
# 5                                      /home/biso/Downloads/CACCIAVILLANI.pdf
# 6                                     /home/biso/Downloads/CVMarioBisonti.pdf
# 7                                           /home/biso/Downloads/heathrow.png
# 8                                    /home/biso/Downloads/MarioBisonti_CV.pdf
# 9                                      /home/biso/Downloads/13590GuidaABF.pdf
# 10                              /home/biso/Downloads/event_map_with_list.html
# 11                                            /home/biso/Downloads/pugile.png
# 12               /home/biso/Downloads/Ord. 78670_report_utenti_gas_178353.pdf
# 13             /home/biso/Downloads/Mario BISONTI_Proficiency Test Result.pdf
# 14                               /home/biso/Downloads/00444-002 Scan_1183.pdf
# 15                                      /home/biso/Downloads/element-keys.txt
# 16                           /home/biso/Downloads/ProRealTime-linux64-3.2.run
# 17                                           /home/biso/Downloads/9123W-1.pdf
# 18                                          /home/biso/Downloads/olimpycs.png
# 19                              /home/biso/Downloads/zona-nord-2025-02-03.pdf
# 20                   /home/biso/Downloads/superlinked-27.2.1-py3-none-any.whl
# 21                 /home/biso/Downloads/Octo Fissa 12M Gas Domestico-16-1.pdf
# 22                                         /home/biso/Downloads/monsters.json
# 23                                   /home/biso/Downloads/UTF-82500910459.pdf
# 24                                 /home/biso/Downloads/13590GuidaABF (1).pdf
# 25                             /home/biso/Downloads/13589ContoTe-Proposta.pdf
# 26                                         /home/biso/Downloads/ioBisonti.jpg
# 27                                             /home/biso/Downloads/forno.jpg
# 28                                    /home/biso/Downloads/9788852032837.lcpl
# 29                                     /home/biso/Downloads/1746686703486.gif
# 30                                            /home/biso/Downloads/palest.mp4
# 31                             /home/biso/Downloads/veneto_locations (1).json
# 32                                        /home/biso/Downloads/SuperMario.jpg
# 33             /home/biso/Downloads/kraken-balances-2025-04-01-2025-04-28.zip
# 34                      /home/biso/Downloads/Contratto polizza PCP9392288.pdf
# 35                            /home/biso/Downloads/ssh-key-2025-08-30.key.pub
# 36                 /home/biso/Downloads/GlobalSign Atlas R3 DV TLS CA 2024 Q4
# 37                                        /home/biso/Downloads/pellicano.jpeg
# 38                                       /home/biso/Downloads/jsquash2024.jpg
# 39          /home/biso/Downloads/kraken-ledgers-2024-01-01-2025-01-01 (1).zip
# 40                                             /home/biso/Downloads/photo.jpg
# 41                                      /home/biso/Downloads/BoardingPass.pdf
# 42                                /home/biso/Downloads/portafoglio-export.xls
# 43                              /home/biso/Downloads/VisuraViaLagoDIseo24.pdf
# 44                                           /home/biso/Downloads/trangle.png
# 45                                     /home/biso/Downloads/aerei_dataset.zip
# 46                                  /home/biso/Downloads/Elenco_Movimenti.pdf
# 47                                        /home/biso/Downloads/peakpx_mod.jpg
# 48         /home/biso/Downloads/kraken-balances-2025-04-01-2024-01-02 (1).zip
# 49                               /home/biso/Downloads/FatturaElettricista.pdf
#
#                                                       Name      Size  \
# 0                                      ProRealTime.desktop       296
# 1   brave-ejhkdoiecgkmdpomoahkdihbcldkgjci-Default.desktop       311
# 2                                                 WiFIEolo        37
# 3                                       cod eolo 906791918         0
# 4                                           ledger2024.pdf     74251
# 5                                        CACCIAVILLANI.pdf    146054
# 6                                       CVMarioBisonti.pdf    199323
# 7                                             heathrow.png    132024
# 8                                      MarioBisonti_CV.pdf    199323
# 9                                        13590GuidaABF.pdf   1514917
# 10                                event_map_with_list.html     86216
# 11                                              pugile.png     66206
# 12                 Ord. 78670_report_utenti_gas_178353.pdf    141615
# 13               Mario BISONTI_Proficiency Test Result.pdf     29571
# 14                                 00444-002 Scan_1183.pdf   8101649
# 15                                        element-keys.txt   1834527
# 16                             ProRealTime-linux64-3.2.run   8241461
# 17                                             9123W-1.pdf    520783
# 18                                            olimpycs.png     82380
# 19                                zona-nord-2025-02-03.pdf    117960
# 20                     superlinked-27.2.1-py3-none-any.whl    534687
# 21                   Octo Fissa 12M Gas Domestico-16-1.pdf    242690
# 22                                           monsters.json      4719
# 23                                     UTF-82500910459.pdf    206100
# 24                                   13590GuidaABF (1).pdf   1514917
# 25                               13589ContoTe-Proposta.pdf    372790
# 26                                           ioBisonti.jpg     77620
# 27                                               forno.jpg     82402
# 28                                      9788852032837.lcpl      2491
# 29                                       1746686703486.gif   1085164
# 30                                              palest.mp4  15931737
# 31                               veneto_locations (1).json      1393
# 32                                          SuperMario.jpg    112347
# 33               kraken-balances-2025-04-01-2025-04-28.zip     32768
# 34                        Contratto polizza PCP9392288.pdf    218122
# 35                              ssh-key-2025-08-30.key.pub       399
# 36                   GlobalSign Atlas R3 DV TLS CA 2024 Q4      1670
# 37                                          pellicano.jpeg     55011
# 38                                         jsquash2024.jpg    141647
# 39            kraken-ledgers-2024-01-01-2025-01-01 (1).zip     32768
# 40                                               photo.jpg     57245
# 41                                        BoardingPass.pdf     24577
# 42                                  portafoglio-export.xls     28672
# 43                                VisuraViaLagoDIseo24.pdf     14823
# 44                                             trangle.png     14171
# 45                                       aerei_dataset.zip     15712
# 46                                    Elenco_Movimenti.pdf     69274
# 47                                          peakpx_mod.jpg   1156508
# 48           kraken-balances-2025-04-01-2024-01-02 (1).zip     32768
# 49                                 FatturaElettricista.pdf     99962
#
#                          ContentType                  Kind  CreationDate  \
# 0                            unknown               unknown    1747409723
# 1                            unknown               unknown    1752434362
# 2                            unknown               unknown    1706870572
# 3                            unknown               unknown    1706870572
# 4                    application/pdf                   pdf    1745871295
# 5                    application/pdf                   pdf    1746636598
# 6                    application/pdf                   pdf    1747389541
# 7                          image/png                   png    1742640171
# 8                    application/pdf                   pdf    1749291865
# 9                    application/pdf                   pdf    1752741756
# 10                         text/html                  html    1755850800
# 11                         image/png                   png    1742640253
# 12                   application/pdf                   pdf    1751814642
# 13                   application/pdf                   pdf    1757770341
# 14                   application/pdf                   pdf    1757517563
# 15                        text/plain                 plain    1747220901
# 16                           unknown               unknown    1750414962
# 17                   application/pdf                   pdf    1752814969
# 18                         image/png                   png    1742656137
# 19                   application/pdf                   pdf    1751924371
# 20                           unknown               unknown    1748704286
# 21                   application/pdf                   pdf    1746188330
# 22                  application/json                  json    1747418665
# 23                   application/pdf                   pdf    1746037052
# 24                   application/pdf                   pdf    1752742228
# 25                   application/pdf                   pdf    1752742216
# 26                        image/jpeg                  jpeg    1750764784
# 27                        image/jpeg                  jpeg    1741436407
# 28                           unknown               unknown    1752654847
# 29                         image/gif                   gif    1746732320
# 30                         video/mp4                   mp4    1751213708
# 31                  application/json                  json    1756827211
# 32                        image/jpeg                  jpeg    1750764806
# 33                   application/zip                   zip    1745870275
# 34                   application/pdf                   pdf    1758004767
# 35  application/vnd.exstream-package  vnd.exstream-package    1756563065
# 36                           unknown               unknown    1749127605
# 37                        image/jpeg                  jpeg    1741690505
# 38                        image/jpeg                  jpeg    1745952780
# 39                   application/zip                   zip    1745871249
# 40                        image/jpeg                  jpeg    1752676052
# 41                   application/pdf                   pdf    1752756491
# 42          application/vnd.ms-excel          vnd.ms-excel    1746205619
# 43                   application/pdf                   pdf    1757515021
# 44                         image/png                   png    1742655916
# 45                   application/zip                   zip    1749741768
# 46                   application/pdf                   pdf    1751112329
# 47                        image/jpeg                  jpeg    1754145176
# 48                   application/zip                   zip    1746113456
# 49                   application/pdf                   pdf    1740577342
#
#     ContentChangeDate
# 0          1747409723
# 1          1752434362
# 2          1607536787
# 3          1580048715
# 4          1745871295
# 5          1746636598
# 6          1747389510
# 7          1742640171
# 8          1749291784
# 9          1752741756
# 10         1755850795
# 11         1742640253
# 12         1751814639
# 13         1757770336
# 14         1757517562
# 15         1747220896
# 16         1750414956
# 17         1752814969
# 18         1742656137
# 19         1751924367
# 20         1748704286
# 21         1746188328
# 22         1747418665
# 23         1746037052
# 24         1752742228
# 25         1752742214
# 26         1750764784
# 27         1741436400
# 28         1752654840
# 29         1746732317
# 30         1751213708
# 31         1756827207
# 32         1750764806
# 33         1745870272
# 34         1758004767
# 35         1756563064
# 36         1749127605
# 37         1741690505
# 38         1745952780
# 39         1745871245
# 40         1752676049
# 41         1752756491
# 42         1746205613
# 43         1757515008
# 44         1742655916
# 45         1749741764
# 46         1751112325
# 47         1754145176
# 48         1746113448
# 49         1740577287

# %% [markdown]
# ## I want to create a collection file_monkesearch

# %% [markdown]
# ```shell
# python3.12.3 -m venv .venv
# . .venv/bin/activate
# pip install -r requirements.txt
# APP_ID=file_monkesearch APP_MODULE_PATH=superlinked_app python -m superlinked.server
# ```

# %% [markdown]
# ## Load linux_dump.jsonl
#
# ```shell
# curl -X POST http://<server-host>:<port>/data-loader/file_document/run -H 'accept: application/json' -d ''
# ```

# %%
# !curl -X POST http://localhost:8080/data-loader/file_document/run -H 'accept: application/json' -d ''
# Out:
# {"result":"Background task successfully started with name: file_document"}
