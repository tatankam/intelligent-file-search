# %% [markdown]
# # File Metadata and Content Index Generator
#
# This Python script automates the creation of a metadata and content index for a simulated filesystem. It generates up to 100 JSON files, each representing a document with a variety of attributes—such as filename, path, size, creation and modification dates, content chunks, file type, and tags.
# This tool is designed to help prototype, test, and develop file-based search, retrieval, or recommendation systems that rely on metadata and content for enhanced searchability.
#
# ## Features
#
# - **Content-Driven Filenames**
#   - Filenames are generated based on the actual content of the file, extracting a keyword from the first content chunk.
#   - The base filename is limited to a maximum of 8 characters (before the file extension).
# - **Randomized File Paths**
#   - Each file is assigned a random path starting from root (`/`), up to three directory levels deep.
# - **Comprehensive Metadata**
#   - **filename** (content-based, up to 8 chars)
#   - **path**
#   - **size** (in kilobytes)
#   - **creation_date** (randomly between 2001 and 2025)
#   - **last_modified_date** (after creation_date, within the same range)
#   - **content_chunks** (1–3 realistic text or table chunks per file)
#   - **file_type** (`xlsx`, `pdf`, `docx`, `txt`, `pptx`, `md`)
#   - **tags** (1–3 tags per file: `sport`, `cinema`, `fashion`, `cars`; some files have multiple tags)
# - **Realistic Content**
#   - Content chunks are generated using the Faker library, ensuring relevance to the assigned tags.
#   - **Text files:** Paragraphs are tailored to the file’s tags.
#   - **Spreadsheets (xlsx):** Tables are generated with relevant headers and sample data.
# - **Flexible Output**
#   - The script outputs a JSON index for each file, making it easy to ingest into search engines, vector databases, or other metadata-driven applications.
#
# ## Example
#
# Each generated JSON file looks like this:

# %% [markdown]
# ```
# {
#   "filename": "basketba.pdf",
#   "path": "/alpha/beta/basketba.pdf",
#   "sizekB": 1234,
#   "last_modified_date": "2023-05-15",
#   "creation_date": "2023-01-10",
#   "content_chunks": [
#     "The basketball player scored a goal. The championship was intense. The athlete trained hard."
#   ],
#   "file_type": "pdf",
#   "tags": ["sport"]
# }
# ```

# %% [markdown]
# ---
#
# ## About Production File Extraction
#
# This script is intended for development and testing. In a production environment, you would typically use specialized tools to extract metadata and content from real files. Here are some examples of how this is done:
#
# - **PDF Documents:**
#   - **Tool:** PyPDF2 or Apache Tika
#   - **What is extracted:**
#     - Basic metadata (author, title, creation/modification dates)
#     - Full text content for indexing or search
# - **Word Documents:**
#   - **Tool:** python-docx or Apache Tika
#   - **What is extracted:**
#     - Document properties (author, title, keywords)
#     - Paragraphs and tables for content analysis
# - **Excel Files:**
#   - **Tool:** openpyxl or Apache Tika
#   - **What is extracted:**
#     - Sheet names, column headers, and cell data
#     - Custom metadata stored in properties
# - **Text Files:**
#   - **Tool:** Built-in Python file handling or Apache Tika
#   - **What is extracted:**
#     - File content for indexing or search
#     - Stat metadata (size, timestamps)
# - **Markdown Files:**
#   - **Tool:** Built-in Python file handling or specialized parsers
#   - **What is extracted:**
#     - Markdown content for rendering or indexing
#     - Front matter (YAML metadata, if present)
#
# These tools and techniques allow you to extract both structured metadata (like creation date and author) and unstructured content (like paragraphs and tables) from a wide range of file formats, supporting robust search and analysis workflows.

# %%
# !pip install faker
# Out:
# Requirement already satisfied: faker in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (37.4.0)
# Requirement already satisfied: tzdata in /home/biso/development/my_projects/.venv/lib/python3.12/site-packages (from faker) (2025.2)

# %%
import os
import json
import random
import re
from datetime import datetime, date, timedelta
from faker import Faker

fake = Faker()

# Ensure output directory exists
os.makedirs('../dataset/generated_files', exist_ok=True)

file_types = ['xlsx', 'pdf', 'docx', 'txt', 'pptx', 'md']
tags_list = ['sport', 'cinema', 'fashion', 'cars']

def random_date(start_year, end_year):
    """Generate a random date between start_year and end_year."""
    year = random.randint(start_year, end_year)
    month = random.randint(1, 12)
    day = random.randint(1, 28)
    return date(year, month, day)

def random_path(max_levels=3):
    """Generate a random path starting with / and up to max_levels deep."""
    levels = random.randint(1, max_levels)
    path = "/"
    for _ in range(levels):
        path += fake.word().lower() + "/"
    return path.rstrip('/')

def clean_filename(keyword):
    """Remove special characters from keyword."""
    cleaned = re.sub(r'[^a-zA-Z0-9_]', '', keyword)
    if not cleaned:
        return "file"
    return cleaned.lower()

def extract_keyword(content_chunk):
    """Extract a unique keyword from the content chunk."""
    words = content_chunk.split()
    for word in words:
        word_lower = word.lower()
        if word_lower not in {'the', 'a', 'an', 'and', 'name', 'title', 'designer', 'model', 'event', 'collection', 'score', 'year', 'brand'}:
            return clean_filename(word)
    # If no unique word found, fall back to a random tag
    return clean_filename(random.choice(['sport', 'cinema', 'fashion', 'cars']))

for i in range(1, 101):
    file_type = random.choice(file_types)
    num_tags = random.randint(1, 3)
    tags = random.sample(tags_list, num_tags) if num_tags <= len(tags_list) else tags_list.copy()
    num_chunks = random.randint(1, 3)
    content_chunks = []
    for _ in range(num_chunks):
        chunk = ""
        if file_type in ['txt', 'md', 'pdf', 'docx', 'pptx']:
            for tag in tags:
                if tag == 'sport':
                    chunk += fake.paragraph(nb_sentences=1, ext_word_list=['football', 'basketball', 'tennis', 'championship', 'athlete']) + " "
                elif tag == 'cinema':
                    chunk += fake.paragraph(nb_sentences=1, ext_word_list=['movie', 'actor', 'director', 'scene', 'award']) + " "
                elif tag == 'fashion':
                    chunk += fake.paragraph(nb_sentences=1, ext_word_list=['dress', 'designer', 'trend', 'runway', 'model']) + " "
                elif tag == 'cars':
                    chunk += fake.paragraph(nb_sentences=1, ext_word_list=['car', 'engine', 'speed', 'model', 'race']) + " "
            content_chunks.append(chunk.strip())
        elif file_type == 'xlsx':
            table = ""
            if 'sport' in tags:
                table += "name,event,score\nJohn,football,3\nLisa,tennis,2\n"
            if 'cinema' in tags:
                table += "title,director,year\nInception,Christopher Nolan,2010\n"
            if 'fashion' in tags:
                table += "designer,collection,season\nChanel,Spring,2023\n"
            if 'cars' in tags:
                table += "model,brand,year\nModel 3,Tesla,2022\n"
            content_chunks.append(table.strip())

    # Extract keyword from first content chunk
    keyword = extract_keyword(content_chunks[0])
    keyword = keyword[:8]  # Truncate to 8 chars
    filename = f"{keyword}.{file_type}"

    path = random_path(max_levels=3) + "/" + filename
    size = random.randint(100, 10000)

    creation_date = random_date(2001, 2025)
    last_modified_date = creation_date + timedelta(days=random.randint(1, (date(2025,12,31) - creation_date).days))
    creation_date = creation_date.isoformat()
    last_modified_date = last_modified_date.isoformat()

    data = {
        "filename": filename,
        "path": path,
        "sizekB": size,
        "last_modified_date": last_modified_date,
        "creation_date": creation_date,
        "content_chunks": content_chunks,
        "file_type": file_type,
        "tags": tags
    }

    with open(f'../dataset/generated_files/file_{i}_index.json', 'w') as f:
        json.dump(data, f, indent=2)

print("Generated 100 JSON index files in 'generated_files' directory!")
# Out:
# Generated 100 JSON index files in 'generated_files' directory!

# %% [markdown]
# # JSON Index to JSONL Combiner
#
# This script reads all JSON metadata files from `../dataset/generated_files` and combines them into a single JSONL file (`../dataset/combined_index.jsonl`). Each line in the resulting file is a standalone JSON object representing the metadata and content of one file.
#
# ## Usage
#
# 1. Place your individual JSON index files in `../dataset/generated_files`.
# 2. Run this script.
# 3. The output will be a JSONL file at `../dataset/combined_index.jsonl`, with one JSON object per line.
#
# **Fields included:**
# - `filename`
# - `path`
# - `sizekB`
# - `last_modified_date`
# - `creation_date`
# - `content_chunks`
# - `file_type`
# - `tags`

# %%
import os
import json
from datetime import datetime, timezone

input_dir = '../dataset/generated_files'
output_file = '../dataset/combined_index.jsonl'

def convert_to_timestamp(datestr):
    try:
        # Convert "YYYY-MM-DD" to timestamp (UTC)
        return int(datetime.fromisoformat(datestr).replace(tzinfo=timezone.utc).timestamp())
    except Exception as e:
        print(f"Error parsing date '{datestr}': {e}")
        return None

def normalize_entry(data, file_id):
    creation_ts = convert_to_timestamp(data.get("creation_date"))
    modified_ts = convert_to_timestamp(data.get("last_modified_date"))

    return {
        "id": file_id,
        "Filename": data.get("filename"),
        "Path": data.get("path"),
        "Size_kB": float(data.get("sizekB", 0)),
        "Content": " ".join(data.get("content_chunks", [])),
        "File_Type": [data.get("file_type")] if data.get("file_type") else [],
        "Tags": data.get("tags", []),
        "Creation_Date": creation_ts,
        "Last_Modified_Date": modified_ts,
    }

with open(output_file, 'w', encoding='utf-8') as outfile:
    file_counter = 1
    for fname in sorted(os.listdir(input_dir)):
        if fname.endswith('.json'):
            with open(os.path.join(input_dir, fname), 'r', encoding='utf-8') as f:
                data = json.load(f)
                normalized = normalize_entry(data, f"id_{file_counter}")
                json.dump(normalized, outfile)
                outfile.write('\n')
                file_counter += 1

print(f"Combined JSONL written to {output_file}")
# Out:
# Combined JSONL written to ../dataset/combined_index.jsonl

# %%
import pandas as pd
import json

# Read the normalized JSONL file into a list of dicts
records = []
with open("../dataset/combined_index.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        records.append(json.loads(line))

# Create DataFrame with a descriptive name
filedf = pd.DataFrame(records)

# Show all content in columns without truncation
pd.set_option('display.max_colwidth', None)

# Print available columns
print(list(filedf.columns))

# Display a few selected columns in a nice format
filedf[[
    "id",
    "Filename",
    "File_Type",
    "Tags",
    "Path",
    "Creation_Date",
    "Last_Modified_Date",
    "Content"
]].head(50)
# Out:
# ['id', 'Filename', 'Path', 'Size_kB', 'Content', 'File_Type', 'Tags', 'Creation_Date', 'Last_Modified_Date']
#        id       Filename File_Type                      Tags  \
# 0    id_1    runway.docx    [docx]          [fashion, sport]
# 1    id_2     tennis.pdf     [pdf]     [sport, cars, cinema]
# 2    id_3       trend.md      [md]  [fashion, cinema, sport]
# 3    id_4       model.md      [md]    [cars, sport, fashion]
# 4    id_5        car.txt     [txt]                    [cars]
# 5    id_6  titledir.xlsx    [xlsx]                  [cinema]
# 6    id_7   football.pdf     [pdf]                   [sport]
# 7    id_8     trend.docx    [docx]                 [fashion]
# 8    id_9     runway.txt     [txt]                 [fashion]
# 9   id_10     speed.pptx    [pptx]   [cars, fashion, cinema]
# 10  id_11      speed.txt     [txt]    [cars, sport, fashion]
# 11  id_12  titledir.xlsx    [xlsx]   [cinema, cars, fashion]
# 12  id_13     award.pptx    [pptx]                  [cinema]
# 13  id_14        car.pdf     [pdf]                    [cars]
# 14  id_15    athlete.txt     [txt]     [sport, cars, cinema]
# 15  id_16      race.pptx    [pptx]     [cars, sport, cinema]
# 16  id_17  designer.xlsx    [xlsx]           [cars, fashion]
# 17  id_18  basketba.pptx    [pptx]                   [sport]
# 18  id_19  nameeven.xlsx    [xlsx]  [cinema, fashion, sport]
# 19  id_20      dress.txt     [txt]          [fashion, sport]
# 20  id_21      race.pptx    [pptx]             [cars, sport]
# 21  id_22      race.pptx    [pptx]     [cars, cinema, sport]
# 22  id_23  designer.xlsx    [xlsx]                 [fashion]
# 23  id_24     actor.pptx    [pptx]  [cinema, sport, fashion]
# 24  id_25       trend.md      [md]    [fashion, sport, cars]
# 25  id_26      engine.md      [md]           [cars, fashion]
# 26  id_27    runway.pptx    [pptx]                 [fashion]
# 27  id_28  titledir.xlsx    [xlsx]         [cinema, fashion]
# 28  id_29      trend.pdf     [pdf]         [fashion, cinema]
# 29  id_30        car.txt     [txt]             [cars, sport]
# 30  id_31  director.docx    [docx]                  [cinema]
# 31  id_32  nameeven.xlsx    [xlsx]    [sport, fashion, cars]
# 32  id_33      award.txt     [txt]                  [cinema]
# 33  id_34        car.pdf     [pdf]                    [cars]
# 34  id_35    tennis.pptx    [pptx]             [sport, cars]
# 35  id_36      trend.pdf     [pdf]                 [fashion]
# 36  id_37     scene.docx    [docx]     [cinema, cars, sport]
# 37  id_38        car.pdf     [pdf]           [cars, fashion]
# 38  id_39     dress.docx    [docx]           [fashion, cars]
# 39  id_40      race.docx    [docx]                    [cars]
# 40  id_41    engine.docx    [docx]    [cars, fashion, sport]
# 41  id_42     trend.pptx    [pptx]          [fashion, sport]
# 42  id_43  titledir.xlsx    [xlsx]                  [cinema]
# 43  id_44     trend.pptx    [pptx]                 [fashion]
# 44  id_45   basketba.pdf     [pdf]             [sport, cars]
# 45  id_46      speed.txt     [txt]     [cars, cinema, sport]
# 46  id_47  nameeven.xlsx    [xlsx]  [sport, fashion, cinema]
# 47  id_48  director.docx    [docx]   [cinema, fashion, cars]
# 48  id_49    engine.docx    [docx]           [cars, fashion]
# 49  id_50  nameeven.xlsx    [xlsx]          [sport, fashion]
#
#                                     Path  Creation_Date  Last_Modified_Date  \
# 0   /land/education/democrat/runway.docx     1447632000          1637452800
# 1       /nearly/could/whether/tennis.pdf     1153180800          1671235200
# 2              /herself/science/trend.md     1540166400          1581033600
# 3                      /address/model.md     1646611200          1684540800
# 4                   /civil/worry/car.txt     1019779200          1200873600
# 5       /environment/close/titledir.xlsx     1070841600          1664841600
# 6        /marriage/anything/football.pdf     1274054400          1489449600
# 7             /event/official/trend.docx     1015545600          1256688000
# 8           /difference/agent/runway.txt     1582156800          1685664000
# 9                  /cause/red/speed.pptx     1502064000          1664582400
# 10                     /itself/speed.txt      978998400          1291593600
# 11     /late/writer/social/titledir.xlsx     1558051200          1598832000
# 12               /opportunity/award.pptx     1588809600          1743811200
# 13                /third/believe/car.pdf     1278288000          1295913600
# 14                     /rest/athlete.txt     1046649600          1502064000
# 15                        /law/race.pptx     1110067200          1434153600
# 16               /consumer/designer.xlsx     1339632000          1597795200
# 17    /none/decade/history/basketba.pptx     1466035200          1627516800
# 18                  /major/nameeven.xlsx     1548547200          1612569600
# 19                          /i/dress.txt     1412553600          1455321600
# 20                     /others/race.pptx     1178755200          1606262400
# 21                       /talk/race.pptx     1681171200          1731801600
# 22           /because/page/designer.xlsx     1406419200          1741478400
# 23                     /place/actor.pptx     1162425600          1329177600
# 24            /born/eight/dream/trend.md     1081209600          1269561600
# 25                 /star/catch/engine.md     1160956800          1487635200
# 26               /themselves/runway.pptx     1619308800          1751155200
# 27                 /manage/titledir.xlsx     1201392000          1476316800
# 28                   /attorney/trend.pdf      978998400          1759708800
# 29                        /since/car.txt     1312156800          1524873600
# 30       /able/might/money/director.docx     1273536000          1714694400
# 31      /fact/high/success/nameeven.xlsx     1040601600          1293753600
# 32                    /perform/award.txt     1502668800          1594771200
# 33  /especially/able/traditional/car.pdf     1493856000          1727827200
# 34                 /leg/full/tennis.pptx     1285200000          1346889600
# 35                      /green/trend.pdf     1756684800          1763337600
# 36        /movement/take/like/scene.docx     1201910400          1378252800
# 37                         /full/car.pdf     1003104000          1158883200
# 38                      /only/dress.docx      989280000          1433808000
# 39       /line/painting/health/race.docx     1002585600          1365292800
# 40   /family/share/according/engine.docx     1520640000          1575244800
# 41                  /specific/trend.pptx     1060128000          1258156800
# 42              /late/base/titledir.xlsx     1675987200          1731196800
# 43            /professor/when/trend.pptx     1144713600          1397088000
# 44        /store/three/star/basketba.pdf     1423008000          1529107200
# 45           /even/image/throw/speed.txt     1613865600          1679702400
# 46        /forward/include/nameeven.xlsx     1375488000          1519084800
# 47                  /maybe/director.docx     1636070400          1700524800
# 48              /word/degree/engine.docx     1222819200          1422835200
# 49         /education/that/nameeven.xlsx     1733529600          1760572800
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Content
# 0                                                                                                                                                                                                                                                                                                                                                                   Runway trend runway runway designer. Championship basketball championship athlete tennis tennis tennis.
# 1                                                                                                                                                                                                                                                                                                                                  Tennis athlete basketball athlete championship championship championship. Engine speed speed car speed race. Award director scene award.
# 2                                                                                   Designer trend runway model runway dress. Movie scene actor movie actor actor. Football athlete basketball athlete basketball basketball basketball. Model designer designer designer. Director movie actor movie scene director. Tennis championship athlete championship tennis. Trend model designer runway. Scene scene award award movie. Football football basketball basketball.
# 3                                                                                                                                                                                                      Model model model. Athlete football basketball basketball championship basketball tennis. Model trend runway runway trend trend dress. Engine speed car model model race speed race. Football athlete tennis championship. Runway model model dress runway designer.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                           Car engine car.
# 5                                                                                                                                                                                                                                                                                                         title,director,year\nInception,Christopher Nolan,2010 title,director,year\nInception,Christopher Nolan,2010 title,director,year\nInception,Christopher Nolan,2010
# 6                                                                                                                                                                                                                                                                                                       Football tennis basketball football. Championship championship basketball championship athlete basketball basketball. Championship championship basketball athlete.
# 7                                                                                                                                                                                                                                                                                                                                                          Designer model model designer trend trend. Dress runway designer designer. Runway model model designer designer.
# 8                                                                                                                                                                                                                                                                                                                                                                                                Designer designer runway. Designer dress designer dress model dress model.
# 9                                                                                                                                                                                                                                                                                                                                                                    Speed car model model model speed speed. Trend trend model model model trend. Scene actor scene actor.
# 10                                                                                                 Speed car model car car race model. Athlete championship athlete football. Trend trend designer runway runway dress designer dress. Engine car model race car car speed. Football football championship championship. Model designer runway runway trend. Model car race speed car model. Tennis basketball football basketball. Designer designer dress dress designer.
# 11                                      title,director,year\nInception,Christopher Nolan,2010\ndesigner,collection,season\nChanel,Spring,2023\nmodel,brand,year\nModel 3,Tesla,2022 title,director,year\nInception,Christopher Nolan,2010\ndesigner,collection,season\nChanel,Spring,2023\nmodel,brand,year\nModel 3,Tesla,2022 title,director,year\nInception,Christopher Nolan,2010\ndesigner,collection,season\nChanel,Spring,2023\nmodel,brand,year\nModel 3,Tesla,2022
# 12                                                                                                                                                                                                                                                                                                                                      Award actor movie movie director actor scene. Scene scene movie award. Actor actor movie director director director award director.
# 13                                                                                                                                                                                                                                                                                                                                                                                                                     Car car car speed car. Speed model speed race model.
# 14                                                                                                                                                                                                                                      Athlete athlete athlete basketball athlete tennis. Engine model model model. Scene scene director director. Tennis tennis championship football football athlete football. Engine engine speed race model. Scene actor scene actor.
# 15                                                                                                                                                                                                                                                           Race speed engine model car. Basketball athlete athlete football. Scene award award actor actor movie. Speed model speed speed speed. Athlete tennis athlete. Actor movie director director actor award actor.
# 16                                                                                                                                                                                                                                                                                                designer,collection,season\nChanel,Spring,2023\nmodel,brand,year\nModel 3,Tesla,2022 designer,collection,season\nChanel,Spring,2023\nmodel,brand,year\nModel 3,Tesla,2022
# 17                                                                                                                                                                                                                                                                                                   Basketball basketball tennis basketball championship. Football football athlete football tennis football athlete football. Athlete championship basketball basketball.
# 18                                                                                                                                                          name,event,score\nJohn,football,3\nLisa,tennis,2\ntitle,director,year\nInception,Christopher Nolan,2010\ndesigner,collection,season\nChanel,Spring,2023 name,event,score\nJohn,football,3\nLisa,tennis,2\ntitle,director,year\nInception,Christopher Nolan,2010\ndesigner,collection,season\nChanel,Spring,2023
# 19                                                                                                                                                                                              Dress trend trend runway. Championship athlete championship tennis football. Model model designer designer runway dress runway dress. Tennis football tennis championship. Runway designer runway. Tennis basketball athlete basketball tennis basketball football athlete.
# 20                                                                                                                                                                                                                                                                                            Race model speed speed car car engine. Tennis championship football. Model speed model race model car engine. Tennis basketball athlete basketball football athlete football.
# 21                                                                                                                                                                                                                                                      Race model race car. Scene director award award director. Championship athlete football athlete. Speed speed model race. Actor director scene. Athlete athlete athlete basketball tennis athlete tennis basketball.
# 22                                                                                                                                                                                                                                                                                                                                                                                                                           designer,collection,season\nChanel,Spring,2023
# 23                                                                                                                                                                                                                                  Actor movie actor scene actor actor. Championship football athlete tennis. Trend model model runway. Actor actor award scene actor scene movie director. Football athlete basketball. Model dress designer designer dress runway trend.
# 24                                                                                                                                     Trend model model designer. Tennis football tennis football tennis tennis football. Speed model speed car car car engine. Dress runway trend. Athlete athlete tennis championship. Race engine speed car engine engine. Model runway dress designer. Tennis tennis championship football athlete. Race model engine car race engine.
# 25                                                                                                                                                                                                                         Engine race model speed car engine. Trend dress designer model designer trend. Car car race engine speed engine. Designer trend designer model model model. Car speed engine car speed car race. Model runway dress trend designer runway dress.
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                          Runway dress trend trend trend.
# 27                                                                                                                                                        title,director,year\nInception,Christopher Nolan,2010\ndesigner,collection,season\nChanel,Spring,2023 title,director,year\nInception,Christopher Nolan,2010\ndesigner,collection,season\nChanel,Spring,2023 title,director,year\nInception,Christopher Nolan,2010\ndesigner,collection,season\nChanel,Spring,2023
# 28                                                                                                                                                                                                                                                           Trend runway dress. Award actor movie movie actor. Runway model runway. Actor actor director director director movie. Runway runway model trend dress runway designer dress. Award movie movie director movie.
# 29                                                                                                                                                                                                                                                                             Car car model engine. Basketball basketball athlete tennis football basketball championship. Speed race engine race race. Championship championship football championship basketball tennis.
# 30                                                                                                                                                                                                                                                                                                                                                           Director scene award movie award. Award award actor scene director scene movie actor. Movie movie award award.
# 31                                                                                                                                                                                                                                                                                                                                   name,event,score\nJohn,football,3\nLisa,tennis,2\ndesigner,collection,season\nChanel,Spring,2023\nmodel,brand,year\nModel 3,Tesla,2022
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                       Award movie actor.
# 33                                                                                                                                                                                                                                                                                                                                                                    Model car car car car engine. Race model model engine engine engine race. Car car car speed race car.
# 34                                                                                                                                                                                                         Tennis tennis tennis basketball. Race race race engine engine race. Football football football football tennis tennis basketball championship. Race speed speed engine race car engine. Championship football athlete. Model car car race car car engine engine.
# 35                                                                                                                                                                                                                                                                                                                                                                                                                            Trend designer designer dress designer dress.
# 36                                                                                                                                                                                                                                                 Scene director scene movie movie scene. Engine model speed. Tennis basketball football athlete tennis tennis. Movie actor actor movie actor. Engine model model. Football football tennis championship football athlete.
# 37                                                                                                                                                                                                             Car car speed race race engine speed. Trend runway runway dress runway designer runway dress. Engine race race model. Designer runway model model designer trend. Race engine car engine race model. Trend runway model designer model designer trend model.
# 38                                                                                                                                                                                                                     Designer designer designer dress dress runway model. Model speed engine model speed speed race. Runway trend trend dress model model. Model car speed speed model car race. Model trend runway trend designer dress model. Car car speed engine car.
# 39                                                                                                                                                                                                                                                                                                                                                                                                                                                    Race speed speed car.
# 40                                                                                                                                                                                                                                               Engine model model model car speed. Model trend designer runway dress. Athlete tennis athlete football. Speed model model race model engine engine. Model runway runway model. Football championship championship athlete.
# 41                                                                                                                                                                                                                                                                                                                                                                     Trend dress runway dress runway. Tennis tennis basketball basketball tennis basketball championship.
# 42                                                                                                                                                                                                                                                                                                                                                              title,director,year\nInception,Christopher Nolan,2010 title,director,year\nInception,Christopher Nolan,2010
# 43                                                                                                                                                                                                                                                                                                                                                                                  Trend runway dress designer runway designer trend. Model designer designer trend dress.
# 44                                                                                                                                                                                                                                                                                                                                                                                   Basketball championship basketball championship championship athlete. Speed car speed.
# 45                                                                                                                                                                                                                                                                                                                                                       Speed car car speed. Movie award scene director movie director director. Championship basketball football athlete.
# 46  name,event,score\nJohn,football,3\nLisa,tennis,2\ntitle,director,year\nInception,Christopher Nolan,2010\ndesigner,collection,season\nChanel,Spring,2023 name,event,score\nJohn,football,3\nLisa,tennis,2\ntitle,director,year\nInception,Christopher Nolan,2010\ndesigner,collection,season\nChanel,Spring,2023 name,event,score\nJohn,football,3\nLisa,tennis,2\ntitle,director,year\nInception,Christopher Nolan,2010\ndesigner,collection,season\nChanel,Spring,2023
# 47                                                                                                                                                                                                                                                                                                                                                      Director scene actor scene. Runway designer dress designer dress runway. Race race race engine engine race car car.
# 48                                                                                                                                                                                                                                                                                                                                                                                                  Model engine speed speed speed race car. Designer dress trend designer.
# 49                                                                                                                                                                                                                                                                        name,event,score\nJohn,football,3\nLisa,tennis,2\ndesigner,collection,season\nChanel,Spring,2023 name,event,score\nJohn,football,3\nLisa,tennis,2\ndesigner,collection,season\nChanel,Spring,2023

# %% [markdown]
# ## Create file_type and tags categories

# %%
import json

file_types = set()
tags = set()

with open(output_file, "r", encoding="utf-8") as f:
    for line in f:
        if not line.strip():
            continue
        obj = json.loads(line)
        # File_Type is a list, so iterate and strip each
        if "File_Type" in obj and obj["File_Type"]:
            file_types.update([ft.strip() for ft in obj["File_Type"]])
        # Tags is a list
        if "Tags" in obj and obj["Tags"]:
            tags.update([t.strip() for t in obj["Tags"]])

result = {
    "FileType": sorted(file_types),
    "Tags": sorted(tags),
}

with open("../dataset/categories.json", "w", encoding="utf-8") as f:
    json.dump(result, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ### Split loading combined_index.jsonl and I created more batches

# %%
import json
import requests

def send_batches(data, batch_size=50):
    for i in range(0, len(data), batch_size):
        batch = data[i:i+batch_size]
        response = requests.post(
            'http://localhost:8080/data-loader/file_document/run',
            json=batch,
            headers={'Accept': 'application/json'}
        )
        print(f"Batch {i//batch_size + 1} response:", response.status_code, response.text)

# Load your full dataset
with open('../dataset/combined_index.jsonl', 'r', encoding='utf-8') as f:
    data = [json.loads(line) for line in f]

send_batches(data, batch_size=10)  # Adjust batch size as needed
# Out:
# Batch 1 response: 202 {"result":"Background task successfully started with name: file_document"}
# Batch 2 response: 202 {"result":"Background task successfully started with name: file_document"}
